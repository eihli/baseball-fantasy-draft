# %%
# The following code imports tools we need.
# It creates a dataframe (similar to an excel table)
# We then clean up the column names and assign the stats
# that we are interested in
ARR_BATTING_DISPLAY = ['Player Name', 'Team', 'Position',
                       'hrs', 'runs', 'rbi', 'ave', 'sb',
                       'adp', 'score_all_stats', 'score_correlated_stats',
                       'rank_all_stats', 'rank_correlated_stats',
                       'percent_from_corr_stats']
import pandas as pd
df_batters = pd.read_csv('projections/FantasyPros_2015.csv')
df_pitchers = pd.read_csv('projections/FantasyPros_2015_P.csv')

arr_batting_cols = df_batters.columns.values
arr_pitching_cols = df_pitchers.columns.values

for i in range(len(arr_batting_cols)):
    arr_batting_cols[i] = arr_batting_cols[i].strip()
for i in range(len(arr_pitching_cols)):
    arr_pitching_cols[i] = arr_pitching_cols[i].strip()

df_batters.columns = arr_batting_cols
df_pitchers.columns = arr_pitching_cols

arr_batting_stats = ['runs', 'rbi', 'hrs', 'sb', 'ave']
arr_pitching_stats = {'all': ['w', 'sv', 'k', 'whip', 'era'],
                      'bowling': ['w', 'sv', 'k'], 'golf': ['whip', 'era']}

arr_correlated_batting_stats = ['runs', 'rbi', 'hrs']a

# %%
# This function compares a player to a dataframe of players.
# Each cell where the player beats a player in the dataframe
# is marked as true. Each cell where a player loses to a player in the
# dataframe is marked as false. We sum all of these cells and get a score.
# 
# The score is how many points they earn against the entire field of
# players.

def compete_batter(player, df, arr_stats):
    t = player[arr_stats] >= df[arr_stats]
    score = t[arr_stats].sum().sum()
    return score

def compete_pitcher(player, df, arr_bowling, arr_golf):
    df_bowling = player[arr_bowling] >= df[arr_bowling]
    df_golf = player[arr_golf] <= df[arr_golf]
    score_golf = df_golf.sum().sum()
    score_bowling = df_bowling.sum().sum()
    score = score_golf + score_bowling
    return score_player

# %% [markdown]
# ## Correlation
#
# Here we can see which stats are most correlated.
# It is quite obvious runs, rbi, and hrs are the most correlated.
# sb is most correlated with ave and rbi, but the correlation is not nearly as strong.

# %%
print df_batters[arr_batting_stats].corr()
print df_pitchers[arr_pitching_stats['all']].corr()
# Out:
#           runs       rbi       hrs        sb       ave
# runs  1.000000  0.961198  0.821524  0.477497  0.718995
# rbi   0.961198  1.000000  0.916435  0.294213  0.692959
# hrs   0.821524  0.916435  1.000000  0.102295  0.511248
# sb    0.477497  0.294213  0.102295  1.000000  0.344716
# ave   0.718995  0.692959  0.511248  0.344716  1.000000
#              w        sv         k      whip       era
# w     1.000000 -0.118307  0.972279 -0.324876 -0.162906
# sv   -0.118307  1.000000 -0.042229 -0.403638 -0.455053
# k     0.972279 -0.042229  1.000000 -0.374514 -0.226772
# whip -0.324876 -0.403638 -0.374514  1.000000  0.855216
# era  -0.162906 -0.455053 -0.226772  0.855216  1.000000

# %% [markdown]
# ## Ranking
# The following table is based off 2015 projections from [FantasyPros.com](http://www.fantasypros.com/mlb/projections/hitters.php)
#
# The score on the rightmost side of the table is calculated by having each player compete against each other player
# for each of the five hitting statistics. Each time the player beats someone else's stat, a point was added
# to their score.
#
# The table is sorted in order of score.
#
# TODO:
# * Create function to allow filtering by position.
# * Add column with each players 2014 ADP (Need a clean ordered list from you, Craig...)
# * See if players contracts expiring are taken into account by the FantasyPros projections. If not, take them into account.

# %%
df_batters['score_all_stats'] = df_batters.apply(compete_batter, df = df_batters,
                                       arr_stats = arr_batting_stats,
                                       axis=1)
df_batters['score_correlated_stats'] = df_batters.apply(compete_batter,
                                       df = df_batters,
                                       arr_stats = arr_correlated_batting_stats,
                                       axis = 1)
df_batters.head()
# Out:
#          Player Name Team     Position   ab  hits  2b  3b  runs  hrs  rbi  bb  \
# 0         Mike Trout  LAA        LF,CF  583   176  36   7   112   32  100  86
# 1     Miguel Cabrera  DET     1B,3B,DH  581   182  38   1    97   32  107  68
# 2   Andrew McCutchen  PIT           CF  564   172  36   5    90   23   89  80
# 3  Giancarlo Stanton  MIA           RF  541   149  31   1    88   37   95  87
# 4      Jose Bautista  TOR  RF,1B,CF,DH  528   139  24   1    94   33   94  88
#
#    sb  cs   so    ave    obp    slg    ops  score_all_stats  \
# 0  23   5  151  0.302  0.392  0.548  0.940             3888
# 1   2   1  107  0.314  0.385  0.546  0.931             3469
# 2  18   7  114  0.304  0.390  0.508  0.898             3834
# 3   8   2  164  0.275  0.375  0.538  0.914             3714
# 4   5   2  100  0.264  0.369  0.496  0.865             3557
#
#    score_correlated_stats
# 0                    2346
# 1                    2346
# 2                    2310
# 3                    2344
# 4                    2345

# %% [markdown]
# ## Ranking Batters
# Below, I store the Average Draft Position of each player in the 'adp'
# column.
#
# I then rank players by a score taking all batting stats into account and
# store that rank in 'rank_all_stats'.
#
# I then rank them by only the three most correlated stats ('hrs', 'runs', 'rbi'), and store that rank in 'rank_correlated_stats'.
#
# If a player ranks higher in all stats than in correlated stats, that means they get more points from 'sb' and 'ave' than the average player. If someone ranks higher in correlated stats than all stats, that means they get the majority of their points from 'rbi', 'hrs', and 'runs'.
#
# The best team is one that works together, so you want to pick players that rank higher on correlated stats than all stats.

# %%
df_batters['adp'] = df_batters.index.values + 1
df_batters = df_batters.sort(columns = 'score_all_stats', ascending = False)
df_batters.index = range(0, len(df_batters.index))
df_batters['rank_all_stats'] = df_batters.index.values + 1
df_batters = df_batters.sort(columns = 'score_correlated_stats',
                             ascending = False)
df_batters.index = range(0, len(df_batters.index))
df_batters['rank_correlated_stats'] = df_batters.index.values + 1
df_batters['percent_from_corr_stats'] = df_batters['score_correlated_stats'] / df_batters['score_all_stats']
df_batters[ARR_BATTING_DISPLAY].head(50)
# Out:
#           Player Name Team     Position  hrs  runs  rbi    ave  sb  adp  \
# 0          Mike Trout  LAA        LF,CF   32   112  100  0.302  23    1
# 1      Miguel Cabrera  DET     1B,3B,DH   32    97  107  0.314   2    2
# 2       Jose Bautista  TOR  RF,1B,CF,DH   33    94   94  0.264   5    5
# 3   Giancarlo Stanton  MIA           RF   37    88   95  0.275   8    4
# 4    Paul Goldschmidt  ARI           1B   29    90   94  0.289  12    7
# 5   Jose Dariel Abreu  CWS        1B,DH   34    86   93  0.295   3    8
# 6   Edwin Encarnacion  TOR     1B,3B,DH   33    84   94  0.265   4   10
# 7       Anthony Rizzo  CHC           1B   31    86   89  0.272   5   18
# 8      Josh Donaldson  TOR           3B   28    88   88  0.270   6   13
# 9          Adam Jones  BAL           CF   27    84   91  0.278   8    9
# 10   Andrew McCutchen  PIT           CF   23    90   89  0.304  18    3
# 11      Adrian Beltre  TEX           3B   24    80   87  0.305   1   11
# 12        Chris Davis  BAL        1B,3B   33    77   84  0.240   3   33
# 13    Freddie Freeman  ATL           1B   22    85   85  0.287   2   35
# 14    Adrian Gonzalez  LAD           1B   22    80   92  0.283   2   36
# 15      Albert Pujols  LAA        1B,DH   24    78   86  0.267   4   55
# 16       Justin Upton   SD        LF,RF   24    79   83  0.260   8   28
# 17    Victor Martinez  DET        1B,DH   22    78   89  0.308   2   20
# 18       Hunter Pence   SF           RF   20    83   87  0.270  11   17
# 19      Matt Holliday  STL           LF   20    82   87  0.276   4   21
# 20      Evan Longoria   TB           3B   23    77   83  0.257   3   45
# 21        Yasiel Puig  LAD        CF,RF   21    85   78  0.295  13   12
# 22        David Ortiz  BOS        1B,DH   25    74   84  0.284   2   51
# 23    Yoenis Cespedes  DET     LF,CF,DH   23    77   81  0.258   7   37
# 24    George Springer  HOU        CF,RF   27    75   78  0.239  18   34
# 25          Jay Bruce  CIN           RF   25    73   80  0.238  10   57
# 26       Bryce Harper  WSH     LF,CF,RF   23    79   77  0.277  11   19
# 27    Troy Tulowitzki  COL           SS   24    75   79  0.307   2   23
# 28       Carlos Gomez  MIL           CF   23    82   72  0.268  30   14
# 29     Carlos Santana  CLE   C,1B,3B,DH   23    75   80  0.245   4   47
# 30       Adam LaRoche  CWS           1B   25    71   81  0.247   2   99
# 31        Mark Trumbo  ARI     1B,LF,RF   28    70   80  0.242   3   60
# 32        Nelson Cruz  SEA     LF,RF,DH   25    70   82  0.249   4   58
# 33      Robinson Cano  SEA           2B   18    80   85  0.296   7   15
# 34        Alex Gordon   KC           LF   18    84   79  0.268  10   29
# 35         Ryan Braun  MIL        LF,RF   22    73   81  0.277  12   24
# 36       Brandon Moss  CLE     1B,LF,RF   28    69   79  0.246   2   59
# 37       Todd Frazier  CIN        3B,1B   24    74   75  0.256  12   42
# 38     Anthony Rendon  WSH        2B,3B   17    85   78  0.276  11   22
# 39       Chris Carter  HOU     1B,LF,DH   29    68   78  0.226   4   81
# 40     Prince Fielder  TEX           1B   22    72   78  0.280   1   80
# 41    Corey Dickerson  COL        LF,CF   22    77   70  0.292   8   26
# 42        Kyle Seager  SEA           3B   21    72   78  0.260   7   52
# 43       Brian Dozier  MIN           2B   19    84   69  0.241  16   61
# 44     Hanley Ramirez  BOS           SS   19    77   75  0.294  14   27
# 45          Matt Kemp   SD     LF,CF,RF   21    72   76  0.277   7   38
# 46        Javier Baez  CHC           SS   25    68   72  0.218  14  116
# 47        Ian Desmond  WSH           SS   21    71   76  0.262  19   50
# 48    Carlos Gonzalez  COL        LF,RF   22    69   74  0.276  11   41
# 49         Lucas Duda  NYM        1B,LF   24    67   72  0.240   2   94
#
#     score_all_stats  score_correlated_stats  rank_all_stats  \
# 0              3888                    2346               1
# 1              3469                    2346              43
# 2              3557                    2345              29
# 3              3714                    2344               6
# 4              3810                    2337               3
# 5              3537                    2336              32
# 6              3515                    2332              34
# 7              3584                    2327              21
# 8              3599                    2324              20
# 9              3703                    2316               7
# 10             3834                    2310               2
# 11             3280                    2292              84
# 12             3151                    2290             116
# 13             3393                    2288              58
# 14             3378                    2284              62
# 15             3478                    2280              42
# 16             3565                    2277              27
# 17             3395                    2273              57
# 18             3658                    2265              12
# 19             3503                    2263              38
# 20             3307                    2261              75
# 21             3747                    2261               4
# 22             3358                    2260              69
# 23             3506                    2258              37
# 24             3415                    2253              54
# 25             3341                    2250              72
# 26             3680                    2250               9
# 27             3369                    2249              66
# 28             3715                    2248               5
# 29             3252                    2244              90
# 30             3096                    2242             136
# 31             3126                    2241             129
# 32             3294                    2240              81
# 33             3636                    2240              14
# 34             3609                    2238              17
# 35             3673                    2233              10
# 36             3074                    2231             142
# 37             3546                    2228              31
# 38             3645                    2224              13
# 39             2984                    2222             161
# 40             3173                    2219             110
# 41             3629                    2211              15
# 42             3468                    2209              44
# 43             3377                    2203              63
# 44             3695                    2203               8
# 45             3557                    2202              28
# 46             3087                    2196             139
# 47             3599                    2195              19
# 48             3608                    2187              18
# 49             2957                    2185             170
#
#     rank_correlated_stats  percent_from_corr_stats
# 0                       1                 0.603395
# 1                       2                 0.676276
# 2                       3                 0.659263
# 3                       4                 0.631125
# 4                       5                 0.613386
# 5                       6                 0.660447
# 6                       7                 0.663442
# 7                       8                 0.649275
# 8                       9                 0.645735
# 9                      10                 0.625439
# 10                     11                 0.602504
# 11                     12                 0.698780
# 12                     13                 0.726753
# 13                     14                 0.674330
# 14                     15                 0.676140
# 15                     16                 0.655549
# 16                     17                 0.638710
# 17                     18                 0.669514
# 18                     19                 0.619191
# 19                     20                 0.646018
# 20                     21                 0.683701
# 21                     22                 0.603416
# 22                     23                 0.673020
# 23                     24                 0.644039
# 24                     25                 0.659736
# 25                     26                 0.673451
# 26                     27                 0.611413
# 27                     28                 0.667557
# 28                     29                 0.605114
# 29                     30                 0.690037
# 30                     31                 0.724160
# 31                     32                 0.716891
# 32                     33                 0.680024
# 33                     34                 0.616062
# 34                     35                 0.620116
# 35                     36                 0.607950
# 36                     37                 0.725764
# 37                     38                 0.628314
# 38                     39                 0.610151
# 39                     40                 0.744638
# 40                     41                 0.699338
# 41                     42                 0.609259
# 42                     43                 0.636967
# 43                     44                 0.652354
# 44                     45                 0.596211
# 45                     46                 0.619061
# 46                     47                 0.711370
# 47                     48                 0.609892
# 48                     49                 0.606153
# 49                     50                 0.738925

# %%
# This is an example of how to filter by position.
center_fielders = df_batters[df_batters.apply(lambda e: 'CF' in e['Position'].split(','), axis=1)]
center_fielders.head()
# Out:
#          Player Name Team     Position   ab  hits  2b  3b  runs  hrs  rbi  \
# 0         Mike Trout  LAA        LF,CF  583   176  36   7   112   32  100
# 2      Jose Bautista  TOR  RF,1B,CF,DH  528   139  24   1    94   33   94
# 9         Adam Jones  BAL           CF  612   170  31   2    84   27   91
# 10  Andrew McCutchen  PIT           CF  564   172  36   5    90   23   89
# 21       Yasiel Puig  LAD        CF,RF  532   157  31   5    85   21   78
#
#    ...     ave    obp    slg    ops  score_all_stats  score_correlated_stats  \
# 0  ...   0.302  0.392  0.548  0.940             3888                    2346
# 2  ...   0.264  0.369  0.496  0.865             3557                    2345
# 9  ...   0.278  0.307  0.468  0.775             3703                    2316
# 10 ...   0.304  0.390  0.508  0.898             3834                    2310
# 21 ...   0.295  0.370  0.490  0.859             3747                    2261
#
#     adp  rank_all_stats  rank_correlated_stats  percent_from_corr_stats
# 0     1               1                      1                 0.603395
# 2     5              29                      3                 0.659263
# 9     9               7                     10                 0.625439
# 10    3               2                     11                 0.602504
# 21   12               4                     22                 0.603416
#
# [5 rows x 24 columns]

# %%
df_batters[ARR_BATTING_DISPLAY].to_csv('Batters_Ranking_1.csv')
